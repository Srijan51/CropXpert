# %% [markdown]
# # 01 — Exploratory Data Analysis: Disease Dataset
#
# Explore the crop disease image dataset (PlantVillage or custom).
#
# ## TODO
# - Load and inspect dataset structure
# - Class distribution analysis
# - Sample image visualization
# - Image quality assessment
