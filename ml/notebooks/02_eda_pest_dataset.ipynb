# %% [markdown]
# # 02 — Exploratory Data Analysis: Pest Dataset
#
# Explore the pest detection dataset with bounding box annotations.
#
# ## TODO
# - Load COCO/YOLO annotations
# - Class distribution and bbox statistics
# - Sample visualization with annotations
