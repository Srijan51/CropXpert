# %% [markdown]
# # 03 — Feature Engineering: Outbreak Risk Forecasting
#
# Prepare weather and historical features for the outbreak risk model.
#
# ## TODO
# - Weather API data integration
# - Feature engineering pipeline
# - Correlation analysis
# - Train/val/test split
